# %%
import pandas as pd 
import csv

# %% [markdown]
# # Default path

# %%
 import os
os.getcwd()
# Out:
# 'C:\\Users\\BLOOMBERG\\Desktop\\PT\\INSEAD\\Universe'

# %% [markdown]
# # Read CSV

# %%
#import necessary modules
import csv
with open('universe.csv','rt')as f:
  data = csv.reader(f)
  for row in data:
        print(row)
# Out:
# ['MAY MK Equity']
# ['TNB MK Equity']
# ['PBK MK Equity']
# ['PCHEM MK Equity']
# ['IHH MK Equity']
# ['CIMB MK Equity']
# ['MAXIS MK Equity']
# ['AXIATA MK Equity']
# ['MISC MK Equity']
# ['HLBK MK Equity']
# ['DIGI MK Equity']
# ['NESZ MK Equity']
# ['SDPL MK Equity']
# ['PTG MK Equity']
# ['IOI MK Equity']
# ['PEP MK Equity']
# ['HAP MK Equity']
# ['PETD MK Equity']
# ['RHBBANK MK Equity']
# ['KLK MK Equity']
# ['GENT MK Equity']
# ['DLG MK Equity']
# ['HLFG MK Equity']
# ['PMAH MK Equity']
# ['GENM MK Equity']
# ['HART MK Equity']
# ['SIME MK Equity']
# ['WPRTS MK Equity']
# ['KLCCSS MK Equity']
# ['T MK Equity']
# ['MAHB MK Equity']
# ['FNH MK Equity']
# ['AMM MK Equity']
# ['QLG MK Equity']
# ['TOPG MK Equity']
# ['YTL MK Equity']
# ['GAM MK Equity']
# ['GENP MK Equity']
# ['CAB MK Equity']
# ['SWB MK Equity']
# ['IJM MK Equity']
# ['HEIM MK Equity']
# ['BIMB MK Equity']
# ['YNS MK Equity']
# ['ASTRO MK Equity']
# ['IGBREIT MK Equity']
# ['INRI MK Equity']
# ['AAGB MK Equity']
# ...

# %%
data = pd.read_csv("universe.csv", header=None) 
data.head()
# Out:
#                  0
# 0    MAY MK Equity
# 1    TNB MK Equity
# 2    PBK MK Equity
# 3  PCHEM MK Equity
# 4    IHH MK Equity

# %% [markdown]
# # Combine into 1 line

# %%
data[0].str.cat(sep=', ')
# Out:
# 'MAY MK Equity, TNB MK Equity, PBK MK Equity, PCHEM MK Equity, IHH MK Equity, CIMB MK Equity, MAXIS MK Equity, AXIATA MK Equity, MISC MK Equity, HLBK MK Equity, DIGI MK Equity, NESZ MK Equity, SDPL MK Equity, PTG MK Equity, IOI MK Equity, PEP MK Equity, HAP MK Equity, PETD MK Equity, RHBBANK MK Equity, KLK MK Equity, GENT MK Equity, DLG MK Equity, HLFG MK Equity, PMAH MK Equity, GENM MK Equity, HART MK Equity, SIME MK Equity, WPRTS MK Equity, KLCCSS MK Equity, T MK Equity, MAHB MK Equity, FNH MK Equity, AMM MK Equity, QLG MK Equity, TOPG MK Equity, YTL MK Equity, GAM MK Equity, GENP MK Equity, CAB MK Equity, SWB MK Equity, IJM MK Equity, HEIM MK Equity, BIMB MK Equity, YNS MK Equity, ASTRO MK Equity, IGBREIT MK Equity, INRI MK Equity, AAGB MK Equity, SDH MK Equity, BAK MK Equity, LPI MK Equity, MBS MK Equity, IOIPG MK Equity, TTNP MK Equity, TDC MK Equity, SREIT MK Equity, KRI MK Equity, PREIT MK Equity, ROTH MK Equity, YTLP MK Equity, STMB MK Equity, UPL MK Equity, UMWH MK Equity, S
# ...
